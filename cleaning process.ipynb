# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Emily\Desktop\dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse Calories
# 0         60  '2020/12/01'    110       130    409.1
# 1         60  '2020/12/02'    117       145      479
# 2         60  '2020/12/03'    103       135      340
# 3         45  '2020/12/04'    109       175    282.4
# 4         45  '2020/12/05'    117       148      406
# 5         60  '2020/12/06'    102       127      300
# 6         60  '2020/12/07'    110       136      374
# 7        450  '2020/12/08'    104       134    253.3
# 8         30  '2020/12/09'    109       133    195.1
# 9         60  '2020/12/10'     98       124      269
# 10        60  '2020/12/11'    103       147    329.3
# 11        60  '2020/12/12'    100       120    250.7
# 12        60  '2020/12/12'    100       120    250.7
# 13        60  '2020/12/13'    106       128    345.3
# 14        60  '2020/12/14'    104       132    379.3
# 15        60  '2020/12/15'     98       123      275
# 16        60  '2020/12/16'     98       120    215.2
# ...

# %%
missing_values=["Na","na","NA","nA","n/a","N/a","N/A","n/A","--"]
df = pd.read_csv(r"C:\Users\Emily\Desktop\dirtydata.csv", na_values = missing_values)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %%
df.dropna(how="all")
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
user = input("How many columns are you have in integer form with null values?:")
y=int(user)
for i in range(y):
 x = input("enter your column name which datatype is inerger or float or any numbers:")
 df[x].fillna(df[x].mean(), inplace = True)
df
# Out:
# How many columns are you have in integer form with null values?:1
# enter your column name which datatype is inerger or float or any numbers:Calories
#     Duration          Date  Pulse  Maxpulse    Calories
# 0         60  '2020/12/01'    110       130  409.100000
# 1         60  '2020/12/02'    117       145  479.000000
# 2         60  '2020/12/03'    103       135  340.000000
# 3         45  '2020/12/04'    109       175  282.400000
# 4         45  '2020/12/05'    117       148  406.000000
# 5         60  '2020/12/06'    102       127  300.000000
# 6         60  '2020/12/07'    110       136  374.000000
# 7        450  '2020/12/08'    104       134  253.300000
# 8         30  '2020/12/09'    109       133  195.100000
# 9         60  '2020/12/10'     98       124  269.000000
# 10        60  '2020/12/11'    103       147  329.300000
# 11        60  '2020/12/12'    100       120  250.700000
# 13        60  '2020/12/13'    106       128  345.300000
# ...

# %%
question = input('do you have datetime column?.......yes or no: ')

if question == "yes":
  column_name = input("enter your column name which is in Date time format:")
  df[column_name] = pd.to_datetime(df[column_name])
else:
    print("print dataset")
# Out:
# do you have datetime column?.......yes or no: yes
# enter your column name which is in Date time format:Date

# %%
df
# Out:
#     Duration       Date  Pulse  Maxpulse    Calories
# 0         60 2020-12-01    110       130  409.100000
# 1         60 2020-12-02    117       145  479.000000
# 2         60 2020-12-03    103       135  340.000000
# 3         45 2020-12-04    109       175  282.400000
# 4         45 2020-12-05    117       148  406.000000
# 5         60 2020-12-06    102       127  300.000000
# 6         60 2020-12-07    110       136  374.000000
# 7        450 2020-12-08    104       134  253.300000
# 8         30 2020-12-09    109       133  195.100000
# 9         60 2020-12-10     98       124  269.000000
# 10        60 2020-12-11    103       147  329.300000
# 11        60 2020-12-12    100       120  250.700000
# 13        60 2020-12-13    106       128  345.300000
# 14        60 2020-12-14    104       132  379.300000
# 15        60 2020-12-15     98       123  275.000000
# 16        60 2020-12-16     98       120  215.200000
# 17        60 2020-12-17    100       120  300.000000
# ...
